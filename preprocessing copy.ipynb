# %% [markdown]
# ##  Exploratory Data Analysis (EDA)
# In this section, we explore the structure, quality, and relationships within the dataset to identify trends, outliers, and correlations related to college completion rates

# %% [markdown]
# ## Step 1: Loading in our Dataset
# We begin by importing the necessary libraries and loading the College Scorecard dataset.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df = pd.read_csv("raw_dataset.csv", low_memory=False)

# %%
df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6484 entries, 0 to 6483
# Columns: 3305 entries, UNITID to MD_EARN_WNE_MALE1_P11
# dtypes: float64(918), int64(15), object(2372)
# memory usage: 163.5+ MB
#              UNITID         OPEID        OPEID6      SCH_DEG         HCM2  \
# count  6.484000e+03  6.458000e+03   6458.000000  6047.000000  6484.000000
# mean   2.261726e+06  1.746369e+06  16983.646175     1.960311     0.006169
# std    7.805306e+06  2.161007e+06  15226.256135     0.901947     0.078307
# min    1.006540e+05  1.002000e+05   1002.000000     1.000000     0.000000
# 25%    1.742222e+05  3.045250e+05   3035.250000     1.000000     0.000000
# 50%    2.288965e+05  1.019803e+06  10152.000000     2.000000     0.000000
# 75%    4.576172e+05  3.083710e+06  30829.750000     3.000000     0.000000
# max    4.966450e+07  8.209882e+07  43064.000000     3.000000     1.000000
#
#               MAIN    NUMBRANCH      PREDDEG      HIGHDEG      CONTROL  ...  \
# ...

# %% [markdown]
# ## Step 2: Exploring the Dataset Structure
# We print out the shape of the dataset (number of institutions and features) and take an initial look at all available column names.

# %%
#Step 2: Exploring the dataset structure we have
print("Shape:(Institutions and Features) ", df.shape)

#familiarizing ourselves with the column names
print("\nColumn feature names:")
#df.columns.to_list()
print("\n".join(df.columns))
# Out:
# Shape:(Institutions and Features)  (6484, 3305)
#
# Column feature names:
# UNITID
# OPEID
# OPEID6
# INSTNM
# CITY
# STABBR
# ZIP
# ACCREDAGENCY
# INSTURL
# NPCURL
# SCH_DEG
# HCM2
# MAIN
# NUMBRANCH
# PREDDEG
# HIGHDEG
# CONTROL
# ST_FIPS
# REGION
# LOCALE
# LOCALE2
# LATITUDE
# LONGITUDE
# CCBASIC
# CCUGPROF
# CCSIZSET
# HBCU
# PBI
# ANNHI
# TRIBAL
# AANAPII
# HSI
# NANTI
# MENONLY
# WOMENONLY
# RELAFFIL
# ADM_RATE
# ADM_RATE_ALL
# SATVR25
# SATVR75
# SATMT25
# SATMT75
# SATWR25
# SATWR75
# SATVRMID
# SATMTMID
# SATWRMID
# ACTCM25
# ACTCM75
# ACTEN25
# ACTEN75
# ACTMT25
# ACTMT75
# ACTWR25
# ACTWR75
# ACTCMMID
# ACTENMID
# ACTMTMID
# ACTWRMID
# SAT_AVG
# SAT_AVG_ALL
# PCIP01
# PCIP03
# PCIP04
# PCIP05
# PCIP09
# PCIP10
# PCIP11
# PCIP12
# PCIP13
# PCIP14
# PCIP15
# PCIP16
# PCIP19
# PCIP22
# PCIP23
# PCIP24
# PCIP25
# PCIP26
# PCIP27
# PCIP29
# PCIP30
# PCIP31
# PCIP38
# PCIP39
# PCIP40
# PCIP41
# PCIP42
# PCIP43
# PCIP44
# PCIP45
# PCIP46
# PCIP47
# PCIP48
# PCIP49
# PCIP50
# ...

# %% [markdown]
# ## Step 3: Selecting Relevant Features for the Study
# To focus our analysis, we manually select a subset of columns from the dataset that are most relevant to our research on college admissions, demographics, finances, and outcomes.

# %%
# Manually defined list of columns relevant to your project
relevant_columns = [
    # Institution info
    "UNITID", "INSTNM", "CITY", "STABBR", "CONTROL", "LOCALE",

    # Admissions & test scores
    "ADM_RATE_ALL","ADMCON7","SAT_AVG", "ACTCMMID",

    #Open admission flag
    "OPENADMP",

    # Student body and diversity
    "UGDS", "UGDS_WHITE", "UGDS_BLACK", "UGDS_HISP", "UGDS_ASIAN", "UGDS_AIAN","UGDS_NHPI","UGDS_2MOR", "UGDS_NRA","UGDS_UNKN",
    "UGDS_MEN", "UGDS_WOMEN", "UG25ABV",

     # First-generation info
    "FIRSTGEN_DEBT_MDN", "NOTFIRSTGEN_DEBT_MDN", "PAR_ED_PCT_1STGEN",

    #Students receiving federal loans and then those receiving pell grants
    "PCTFLOAN", "PCTPELL",

    #RAW DATA SUBMITTED BY THE SCHOOLS: Students receiving federal loans and then those receiving pell grants
    "PCTFLOAN_DCS","PCTPELL_DCS",

    #Family Income and Contributions
    "FAMINC","MD_FAMINC",

    #Financial and aid-related
    "TUITIONFEE_IN", "TUITIONFEE_OUT", "COSTT4_A", "AVGFACSAL", 'DEBT_MDN', "GRAD_DEBT_MDN",

    # Outcome metrics
    "RET_FT4", "C150_4", "COMPL_RPY_3YR_RT",
    "MD_EARN_WNE_INC1_P10", "MD_EARN_WNE_INC2_P10", "MD_EARN_WNE_INC3_P10"
]

#we can then filter and display the columns that seem most relevant to this study
df_relevant = df[relevant_columns]

df_relevant.head()
# Out:
#    UNITID                               INSTNM        CITY STABBR  CONTROL  \
# 0  100654             Alabama A & M University      Normal     AL        1
# 1  100663  University of Alabama at Birmingham  Birmingham     AL        1
# 2  100690                   Amridge University  Montgomery     AL        2
# 3  100706  University of Alabama in Huntsville  Huntsville     AL        1
# 4  100724             Alabama State University  Montgomery     AL        1
#
#    LOCALE  ADM_RATE_ALL  ADMCON7  SAT_AVG  ACTCMMID  ...  COSTT4_A  AVGFACSAL  \
# 0    12.0      0.683956      5.0    920.0      18.0  ...   23167.0     8651.0
# 1    12.0      0.866794      5.0   1291.0      27.0  ...   26257.0    11837.0
# 2    12.0           NaN      NaN      NaN       NaN  ...       NaN     4134.0
# 3    12.0      0.781043      5.0   1259.0      28.0  ...   25777.0    10267.0
# 4    12.0      0.965978      5.0    963.0      18.0  ...   21900.0     8071.0
#
# ...

# %% [markdown]
# ## Step 4: Assessing Missing Data
# We check each selected feature to see how many missing values it contains and what percentage of the total dataset that represents. This helps us decide how to handle these missing entries.

# %%
missing = df_relevant.isnull().sum()
missing_percent = (missing / len(df_relevant)) * 100

missing_df = pd.DataFrame({
    'Missing Values': missing,
    '% of Total': missing_percent
}).sort_values(by='% of Total', ascending=False)

missing_df = missing_df[missing_df['Missing Values'] > 0]  # Only show ones with missing
missing_df
# Out:
#                       Missing Values  % of Total
# ACTCMMID                        5500   84.824183
# SAT_AVG                         5395   83.204812
# ADMCON7                         4498   69.370759
# RET_FT4                         4390   67.705120
# ADM_RATE_ALL                    4269   65.838988
# C150_4                          4204   64.836521
# COSTT4_A                        3168   48.858729
# MD_EARN_WNE_INC3_P10            2715   41.872301
# MD_EARN_WNE_INC2_P10            2715   41.872301
# MD_EARN_WNE_INC1_P10            2715   41.872301
# TUITIONFEE_OUT                  2713   41.841456
# TUITIONFEE_IN                   2713   41.841456
# AVGFACSAL                       2596   40.037014
# COMPL_RPY_3YR_RT                1135   17.504627
# UG25ABV                          949   14.636027
# OPENADMP                         900   13.880321
# PCTPELL                          813   12.538556
# PCTFLOAN                         813   12.538556
# ...

# %% [markdown]
# ### Missing Data Heatmap

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title("Missing Data Heatmap")
plt.show()

# %% [markdown]
# #### Removing rows where completion rate is reported as 0 or null.

# %%
print("Zero values:", (df_relevant['C150_4'] == 0).sum())
print("Null values:", df_relevant['C150_4'].isnull().sum())
df_relevant = df_relevant[df_relevant['C150_4'] != 0]
df_relevant = df_relevant.dropna(subset=['C150_4'])
# Out:
# Zero values: 44
# Null values: 4204

# %%
print("Zero values:", (df_relevant['C150_4'] == 0).sum())
print("Null values:", df_relevant['C150_4'].isnull().sum())
# Out:
# Zero values: 0
# Null values: 0

# %% [markdown]
# ## Step 5: Impute Missing Values
# In this step, we handle missing values for specific columns by filling them with the median value within each institution type (`CONTROL`). This ensures that missing values are replaced with appropriate data based on the institution's characteristics (Public, Private nonprofit, Private for-profit).

# %%
# Columns to impute
impute_columns = [
    'SAT_AVG', 'ADM_RATE_ALL', 'COSTT4_A',
    'TUITIONFEE_IN', 'TUITIONFEE_OUT',
    'AVGFACSAL', 'MD_EARN_WNE_INC1_P10',
    'MD_EARN_WNE_INC2_P10', 'MD_EARN_WNE_INC3_P10'
]

# Group by 'CONTROL' (1 = Public, 2 = Private nonprofit, 3 = Private for-profit)
group_col = 'CONTROL'

# Fill missing values with group median
for col in impute_columns:
    df_relevant[col] = df_relevant.groupby(group_col)[col].transform(lambda x: x.fillna(x.median()))

#if all 0's are returned, then the imputation has successfully worked on the dataset
df_relevant[impute_columns].isna().sum()
# Out:
# SAT_AVG                 0
# ADM_RATE_ALL            0
# COSTT4_A                0
# TUITIONFEE_IN           0
# TUITIONFEE_OUT          0
# AVGFACSAL               0
# MD_EARN_WNE_INC1_P10    0
# MD_EARN_WNE_INC2_P10    0
# MD_EARN_WNE_INC3_P10    0
# dtype: int64

# %% [markdown]
# ## Step 6 - Feature Engineering
#
# Based on our analysis, we create new features to capture important differences such as cost burden and socioeconomic disparities. These engineered features may improve our models and reveal new insights.

# %%
# Tuition Gap: Difference between out-of-state and in-state tuition
df_relevant['TUITION_GAP'] = df_relevant['TUITIONFEE_OUT'] - df_relevant['TUITIONFEE_IN']

# Pell Grant Difference: To compare direct school submissions vs derived stats
df_relevant['PELL_GAP'] = df_relevant['PCTPELL_DCS'] - df_relevant['PCTPELL']

# Display the new columns
df_relevant[['TUITIONFEE_IN', 'TUITIONFEE_OUT', 'TUITION_GAP', 'PCTPELL', 'PCTPELL_DCS', 'PELL_GAP']].head()
# Out:
#    TUITIONFEE_IN  TUITIONFEE_OUT  TUITION_GAP  PCTPELL  PCTPELL_DCS  PELL_GAP
# 0        10024.0         18634.0       8610.0   0.6536       0.6553    0.0017
# 1         8832.0         21216.0      12384.0   0.3308       0.3374    0.0066
# 2        31970.0         32006.0         36.0   0.7769       0.7769    0.0000
# 3        11878.0         24770.0      12892.0   0.2173       0.2235    0.0062
# 4        11068.0         19396.0       8328.0   0.6976       0.6984    0.0008

# %% [markdown]
# ## Step 7 - Visualizing Key Variables
#
# In this section, we create visualizations to better understand the distribution and relationships of key features in our dataset. This helps us identify patterns, outliers, and associations that may influence college outcomes like completion rates.

# %%
# Histograms for numerical features
numeric_cols = ['SAT_AVG', 'C150_4', 'TUITIONFEE_IN', 'TUITIONFEE_OUT', 'COSTT4_A',
                'RET_FT4', 'MD_EARN_WNE_INC1_P10', 'MD_EARN_WNE_INC2_P10','MD_EARN_WNE_INC3_P10']

df_relevant[numeric_cols].hist(figsize=(15, 12), bins=15)
plt.suptitle("Distribution of Key Numeric Features", fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
df_relevant['ADMITTED'] = (df_relevant['SAT_AVG'] >= 1150).astype(int)

plt.figure(figsize=(6, 4))
sns.countplot(x='ADMITTED', data=df_relevant)
plt.title("Class Distribution: Admitted Based on SAT_AVG ≥ 1150")
plt.xlabel("Admitted (1 = Yes, 0 = No)")
plt.ylabel("Number of Schools")
plt.show()

# %%
#Box Plots by Public vs Private Schools
# Convert 'CONTROL' to readable labels
control_map = {1: 'Public', 2: 'Private Non-Profit', 3: 'Private For-Profit'}
df_relevant['CONTROL_LABEL'] = df_relevant['CONTROL'].map(control_map)

# Box plot for tuition by control type
plt.figure(figsize=(10, 6))
sns.boxplot(x='CONTROL_LABEL', y='TUITIONFEE_IN', data=df_relevant)
plt.title("In-State Tuition by Institution Type")
plt.ylabel("In-State Tuition ($)")
plt.xlabel("Institution Type")
plt.xticks(rotation=15)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='CONTROL', y='C150_4', data=df_relevant)
plt.title("4-Year Completion Rate by Institution Type (CONTROL)")
plt.xlabel("Institution Type (CONTROL)")
plt.ylabel("Completion Rate (C150_4)")
plt.show()

# %%
# Visualize the Tuition Gap
plt.figure(figsize=(8, 5))
sns.histplot(df_relevant['TUITION_GAP'], kde=True, bins=30)
plt.title("Distribution of Tuition Gap (Out-of-State - In-State)")
plt.xlabel("Tuition Gap ($)")
plt.show()

# %%
# Create a mapping for LOCALE_GROUP based on LOCALE values
locale_map = {
    11.0: 'City', 12.0: 'City', 13.0: 'City',
    21.0: 'Suburb', 22.0: 'Suburb', 23.0: 'Suburb',
    31.0: 'Town', 32.0: 'Town',  33.0: 'Town',
    41.0: 'Rural', 42.0: 'Rural', 43.0: 'Rural'
}

# Add a new column 'LOCALE_GROUP' to the DataFrame
df_relevant['LOCALE_GROUP'] = df_relevant['LOCALE'].map(locale_map)

# Count and sort locale groupings
locale_counts = df_relevant['LOCALE_GROUP'].value_counts().sort_values(ascending=False)

# Create bar chart
fig, ax = plt.subplots(figsize=(8, 5))
bars = ax.bar(locale_counts.index, locale_counts.values, color='teal')

# Add value labels above each bar
for bar in bars:
    height = bar.get_height()
    ax.annotate(f'{int(height)}',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 5),  # offset above bar
                textcoords="offset points",
                ha='center', va='bottom', fontsize=9)

# Customize plot
ax.set_title("Institution Count by Locale", fontsize=14)
ax.set_xlabel("Locale")
ax.set_ylabel("Number of Institutions")
ax.set_ylim(0, locale_counts.max() * 1.10)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 7.1 – Visualizing Feature Relationships with C150_4

# %%
#Scatter Plot: SAT vs Completion Rate
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df_relevant, x='SAT_AVG', y='C150_4', hue='CONTROL_LABEL')
plt.title("SAT Scores vs 4-Year Completion Rate")
plt.xlabel("Average SAT Score")
plt.ylabel("4-Year Completion Rate")
plt.legend(title="Institution Type")
plt.grid(True)
plt.show()

# %%
sns.histplot(df_relevant['C150_4'], bins=30, kde=True)
plt.title("Distribution of 4-Year Completion Rate (C150_4)")
plt.xlabel("C150_4")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='COSTT4_A', y='C150_4', data=df_relevant)
plt.title("Cost of Attendance vs 4-Year Completion Rate")
plt.xlabel("Cost of Attendance (COSTT4_A)")
plt.ylabel("Completion Rate (C150_4)")
plt.show()

# %% [markdown]
# ## Step 8 - Exploring Correlation with the Target Variable (`C150_4`)

# %% [markdown]
# ### Correlation Matrix
# We compute the correlation matrix between all numeric features and our target variable (C150_4, the 4-year completion rate). This allows us to identify which features are most linearly associated with the target. In particular, later we isolate features with strong correlations (e.g., absolute value > 0.3) to use in further feature selection and modeling. This helps reduce dimensionality and noise in our data.

# %%
# Compute correlation matrix for numeric features
corr_matrix = df_relevant.select_dtypes(include=['number']).corr()

# View correlation with the target variable (C150_4)
target_corr = corr_matrix["C150_4"]

# Display the correlations with the target, sorted in descending order
target_corr_sorted = target_corr.sort_values(ascending=False)

target_corr_sorted
# Out:
# C150_4                  1.000000
# ACTCMMID                0.820422
# TUITIONFEE_OUT          0.586004
# COSTT4_A                0.542704
# RET_FT4                 0.522038
# MD_EARN_WNE_INC1_P10    0.520455
# SAT_AVG                 0.519467
# TUITIONFEE_IN           0.518154
# MD_EARN_WNE_INC2_P10    0.463679
# AVGFACSAL               0.446848
# MD_EARN_WNE_INC3_P10    0.426503
# OPENADMP                0.366986
# ADMITTED                0.321709
# UGDS_ASIAN              0.308760
# UGDS_WHITE              0.192661
# UGDS_NRA                0.189540
# CONTROL                 0.138231
# UGDS                    0.133170
# ADMCON7                 0.120295
# UGDS_2MOR               0.112997
# TUITION_GAP             0.035965
# PCTFLOAN                0.030972
# UGDS_WOMEN              0.016501
# PCTFLOAN_DCS           -0.008094
# UGDS_MEN               -0.021375
# UGDS_UNKN              -0.044252
# UNITID                 -0.074750
# UGDS_NHPI              -0.082045
# ...

# %% [markdown]
# ### Why these values matter:
# We used correlation-based feature selection to identify variables that are strongly associated with 4-year completion rates (C150_4). This helps reduce noise and multicollinearity in our dataset. C150_4 was chosen as our target because it is a key measure of college success, making it a meaningful outcome to model and understand
# This helps us identify whether demographic, financial, or academic prep variables (e.g., SAT, Pell Grants, etc.) relate to college success.
# Many students get admitted to college, but not all finish in 4 years
# - Positive values (closer to 1.00) → as that variable increases, the 4-year grad rate tends to increase.
#
# - Negative values (closer to -1.00) → as that variable increases, the 4-year grad rate tends to decrease.
# - Closer to 0 → weak or no relationship.
#
# We set a threshold so that we can keep the more meaningful correlated features with the taget.

# %%
strong_corr_features = target_corr_sorted[abs(target_corr_sorted) > 0.3]
strong_corr_features
# Out:
# C150_4                  1.000000
# ACTCMMID                0.820422
# TUITIONFEE_OUT          0.586004
# COSTT4_A                0.542704
# RET_FT4                 0.522038
# MD_EARN_WNE_INC1_P10    0.520455
# SAT_AVG                 0.519467
# TUITIONFEE_IN           0.518154
# MD_EARN_WNE_INC2_P10    0.463679
# AVGFACSAL               0.446848
# MD_EARN_WNE_INC3_P10    0.426503
# OPENADMP                0.366986
# ADMITTED                0.321709
# UGDS_ASIAN              0.308760
# ADM_RATE_ALL           -0.303107
# UG25ABV                -0.332844
# PCTPELL                -0.405709
# PCTPELL_DCS            -0.481952
# Name: C150_4, dtype: float64

# %% [markdown]
# ### What we see:
# We performed a correlation-based feature selection using a threshold of 0.3 to retain features with the strongest linear relationship with our target variable, C150_4 (4-year completion rate). This reduced our feature set to 18 variables, including 13 positively correlated and 3 negatively correlated features. This selection helps simplify our model and focus on factors most associated with college completion.
# - Notably, standardized test scores (ACT, SAT), cost-related variables (tuition, average faculty salary), and retention rate showed strong positive associations.
# - Meanwhile, indicators related to older student populations and financial aid (Pell Grants) were negatively associated with 4-year completion outcomes. These insights help guide which factors matter most in predicting college completion.

# %% [markdown]
# ### Correlation Heatmap
#
# To better understand relationships between numerical variables, we use a correlation heatmap. This allows us to see which features are positively or negatively associated with each other.

# %%
# Create a correlation matrix with just the strongly correlated features
strong_corr_df = df_relevant[strong_corr_features.index]
strong_corr_matrix = strong_corr_df.corr()

# Plot the heatmap with just the strongly correlated features
plt.figure(figsize=(12, 10))
sns.heatmap(strong_corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", square=True, linewidths=0.5)
plt.title("Correlation Heatmap of Strongly Correlated Features with C150_4", fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 9 - Feature Selection with RFE (Recursive Feature Elimination)
# To further refine our feature set, we apply RFE using a linear regression model. This method recursively removes the least important features based on the model's coefficients, allowing us to identify the top predictors of completion rate. After this process, we retain only the 10 most impactful features, which simplifies the model while maintaining predictive power.

# %%
# Step 8: Recursive Feature Elimination (RFE)

from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.preprocessing import StandardScaler

# Subset the DataFrame to include only the selected features and target
strong_corr_features_list = strong_corr_features.index.tolist()
df_rfe = df_relevant[strong_corr_features_list + ['C150_4']].copy()

# Ensure all columns are numeric
df_rfe = df_rfe.apply(pd.to_numeric, errors='coerce')

# Drop any rows with missing values
df_rfe.dropna(inplace=True)

# Separate predictors and target
X = df_rfe.drop(columns=['C150_4'])
y = df_rfe['C150_4']

# Standardize the predictors
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Initialize the model and RFE
model = LinearRegression()
rfe = RFE(model, n_features_to_select=10)
rfe.fit(X_scaled, y)

# Get selected features
selected_features = X.columns[rfe.support_]
print("Selected features from RFE:", selected_features.tolist())

# Create a final DataFrame with selected features and the target
final_df = df_rfe[selected_features.tolist() + ['C150_4']]

# drop duplicate columns
final_df = final_df.loc[:, ~final_df.columns.duplicated()]


# Save the preprocessed DataFrame to a CSV file
final_df.to_csv("processed.csv", index=False)
# Out:
# Selected features from RFE: ['ACTCMMID', 'COSTT4_A', 'RET_FT4', 'MD_EARN_WNE_INC1_P10', 'SAT_AVG', 'TUITIONFEE_IN', 'OPENADMP', 'UG25ABV', 'PCTPELL', 'PCTPELL_DCS']
